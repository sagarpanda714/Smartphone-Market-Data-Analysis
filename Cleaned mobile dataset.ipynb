# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\sagar panda\OneDrive\Desktop\Cleaned mobile data set.xlsx")
df
# Out:
#      Unnamed: 0 Company Name            Model Name  Mobile Weight(in gram)  \
# 0             0        Apple       iPhone 16 128GB                   174.0
# 1             1        Apple       iPhone 16 256GB                   174.0
# 2             2        Apple       iPhone 16 512GB                   174.0
# 3             3        Apple  iPhone 16 Plus 128GB                   203.0
# 4             4        Apple  iPhone 16 Plus 256GB                   203.0
# ..          ...          ...                   ...                     ...
# 923         925         POCO          Pad 5G 128GB                   571.0
# 924         926         POCO          Pad 5G 256GB                   571.0
# 925         927      Samsung  Galaxy Z Fold6 256GB                   239.0
# 926         928      Samsung  Galaxy Z Fold6 512GB                   239.0
# 927         929      Samsung    Galaxy Z Fold6 1TB                   239.0
#
#      RAM(in GB)     Front Camera Back Camera            Processor  \
# ...

# %%
df.shape
# Out:
# (928, 16)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.shape
# Out:
# (928, 15)

# %% [markdown]
# # Observation:- Total no.of rows=928 and Total no.of columns=15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Company Name                     928 non-null    object
#  1   Model Name                       928 non-null    object
#  2   Mobile Weight(in gram)           928 non-null    float64
#  3   RAM(in GB)                       928 non-null    float64
#  4   Front Camera                     928 non-null    object
#  5   Back Camera                      928 non-null    object
#  6   Processor                        928 non-null    object
#  7   Battery Capacity(in mAh)         928 non-null    int64
#  8   Screen Size                      928 non-null    object
#  9   Launched Price(Pakistan) in PKR  928 non-null    int64
#  10  Launched Price(India) in INR     928 non-null    int64
#  11  Launched Price(China) in CNY     928 non-null    int64
# ...

# %% [markdown]
# # Observation:- Total 8 column are continuous variable, 6 are discrete and 1 is in date time format.

# %%
df.isnull().sum()
# Out:
# Company Name                       0
# Model Name                         0
# Mobile Weight(in gram)             0
# RAM(in GB)                         0
# Front Camera                       0
# Back Camera                        0
# Processor                          0
# Battery Capacity(in mAh)           0
# Screen Size                        0
# Launched Price(Pakistan) in PKR    0
# Launched Price(India) in INR       0
# Launched Price(China) in CNY       0
# Launched Price(USA) in USD         0
# Launched Price(Dubai) in AED       0
# Launched Year                      0
# dtype: int64

# %% [markdown]
# # Observation:- No null values in any column.

# %%
df.columns.tolist()
# Out:
# ['Company Name',
#  'Model Name',
#  'Mobile Weight(in gram)',
#  'RAM(in GB)',
#  'Front Camera',
#  'Back Camera',
#  'Processor',
#  'Battery Capacity(in mAh)',
#  'Screen Size',
#  'Launched Price(Pakistan) in PKR',
#  'Launched Price(India) in INR',
#  'Launched Price(China) in CNY',
#  'Launched Price(USA) in USD',
#  'Launched Price(Dubai) in AED',
#  'Launched Year']

# %% [markdown]
# # Observation :- No need to use .strip() to remove whitespace in front and back of any column.

# %%
df["Company Name"].unique()
# Out:
# array(['Apple', 'Samsung', 'OnePlus', 'Vivo', 'iQOO', 'Oppo', 'Realme',
#        'Xiaomi', 'Lenovo', 'Motorola', 'Huawei', 'Nokia', 'Sony',
#        'Google', 'Tecno', 'Infinix', 'Honor', 'POCO'], dtype=object)

# %%
df["Company Name"].nunique()
# Out:
# 18

# %% [markdown]
# # Observation:- Total 18 unique company name are there

# %%
df["Company Name"].value_counts()
# Out:
# Company Name
# Oppo        129
# Apple        97
# Honor        91
# Samsung      88
# Vivo         86
# Realme       69
# Motorola     62
# Infinix      56
# OnePlus      53
# Huawei       40
# Tecno        39
# POCO         32
# Xiaomi       27
# Google       21
# Lenovo       15
# Nokia        11
# Sony          9
# iQOO          3
# Name: count, dtype: int64

# %%
df["Company Name"].mode()
# Out:
# 0    Oppo
# Name: Company Name, dtype: object

# %% [markdown]
# # Observation:- Maximum mobile are from oppo

# %%
df["Company Name"].describe()
# Out:
# count      928
# unique      18
# top       Oppo
# freq       129
# Name: Company Name, dtype: object

# %%
df["Model Name"].unique()
# Out:
# array(['iPhone 16 128GB', 'iPhone 16 256GB', 'iPhone 16 512GB',
#        'iPhone 16 Plus 128GB', 'iPhone 16 Plus 256GB',
#        'iPhone 16 Plus 512GB', 'iPhone 16 Pro 128GB',
#        'iPhone 16 Pro 256GB', 'iPhone 16 Pro 512GB',
#        'iPhone 16 Pro Max 128GB', 'iPhone 16 Pro Max 256GB',
#        'iPhone 16 Pro Max 512GB', 'iPhone 15 128GB', 'iPhone 15 256GB',
#        'iPhone 15 512GB', 'iPhone 15 Plus 128GB', 'iPhone 15 Plus 256GB',
#        'iPhone 15 Plus 512GB', 'iPhone 15 Pro 128GB',
#        'iPhone 15 Pro 256GB', 'iPhone 15 Pro 512GB',
#        'iPhone 15 Pro Max 128GB', 'iPhone 15 Pro Max 256GB',
#        'iPhone 15 Pro Max 512GB', 'iPhone 14 128GB', 'iPhone 14 256GB',
#        'iPhone 14 512GB', 'iPhone 14 Plus 128GB', 'iPhone 14 Plus 256GB',
#        'iPhone 14 Plus 512GB', 'iPhone 14 Pro 128GB',
#        'iPhone 14 Pro 256GB', 'iPhone 14 Pro 512GB',
#        'iPhone 14 Pro Max 128GB', 'iPhone 14 Pro Max 256GB',
# ...

# %%
df["Model Name"].nunique()
# Out:
# 906

# %%
df["Model Name"].duplicated().sum()
# Out:
# 22

# %% [markdown]
# # Observation:- Out of 928, 906 are unique model name and 22 are duplicated.

# %%
df["Model Name"].value_counts()
# Out:
# Model Name
# Pad 2 256GB           3
# Pad 128GB             3
# K9 5G 256GB           2
# K7x 128GB             2
# Pad 3 Pro 256GB       2
#                      ..
# V27 Pro 128GB         1
# V27 Pro 256GB         1
# V25 Pro 128GB         1
# V25 Pro 256GB         1
# Galaxy Z Fold6 1TB    1
# Name: count, Length: 906, dtype: int64

# %%
df["Model Name"].mode()
# Out:
# 0      Pad 128GB
# 1    Pad 2 256GB
# Name: Model Name, dtype: object

# %% [markdown]
# # Observation:- These two models are more frequent
# # 0 Pad 128GB
# # 1 Pad 2 256GB

# %%
df["Mobile Weight(in gram)"].unique()
# Out:
# array([174. , 203. , 206. , 221. , 171. , 172. , 140. , 204. , 238. ,
#        135. , 164. , 189. , 228. , 194. , 188. , 226. , 177. , 208. ,
#        458. , 490. , 300.5, 468. , 682. , 708. , 234. , 196. , 168. ,
#        195. , 167. , 254. , 187. , 263. , 199. , 190. , 202. , 198. ,
#        192. , 235. , 191. , 181. , 178. , 175. , 165. , 143. , 229. ,
#        732. , 586. , 498. , 523. , 726. , 567. , 503. , 480. , 366. ,
#        508. , 433. , 674. , 426. , 360. , 205. , 179. , 200. , 183. ,
#        185. , 180. , 173. , 184. , 170. , 162. , 210. , 155. , 215. ,
#        550. , 610. , 223. , 150. , 146. , 158. , 163. , 153. , 176. ,
#        201. , 193. , 159. , 156. , 182. , 535. , 510. , 500. , 560. ,
#        520. , 540. , 555. , 239. , 186. , 533. , 218. , 207. , 233. ,
#        222.8, 440. , 482. , 466. , 499. , 372. , 465. , 209. , 166. ,
#        169. , 295. , 255. , 197. , 225. , 220. , 241. , 245. , 161. ,
# ...

# %%
df["Mobile Weight(in gram)"].nunique()
# Out:
# 148

# %% [markdown]
# # Observation:- Total 148 unique weight in "mobile weight" column

# %%
df["Mobile Weight(in gram)"].value_counts()
# Out:
# Mobile Weight(in gram)
# 190.0    68
# 195.0    64
# 185.0    29
# 192.0    26
# 180.0    25
#          ..
# 151.0     1
# 212.0     1
# 540.0     1
# 216.0     1
# 360.0     1
# Name: count, Length: 148, dtype: int64

# %% [markdown]
# # Observation:- Total 68 mobile phones whose weight are 190 and 190 will be the mode also for "Mobile Weight(in gram)".

# %%
df["Mobile Weight(in gram)"].describe()
# Out:
# count    928.000000
# mean     228.321552
# std      105.539546
# min      135.000000
# 25%      185.000000
# 50%      194.000000
# 75%      208.250000
# max      732.000000
# Name: Mobile Weight(in gram), dtype: float64

# %% [markdown]
# # Observation:-
# # Most mobile devices in your dataset are relatively lightweight (between 135g and 208g).
# # The mean is much higher than the median (228 > 194), suggesting a right-skewed distribution — this happens due to outliers on the heavier side.
# # The max weight of 732g is unusually high — consider:
# # Verifying if this is a tablet or a data entry error.

# %%
q1=df["Mobile Weight(in gram)"].quantile(0.25)
q3=df["Mobile Weight(in gram)"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["Mobile Weight(in gram)"][(df["Mobile Weight(in gram)"]<ll) | (df["Mobile Weight(in gram)"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
outliers.shape[0]
# Out:
# Q1 =  185.0
# Q3 =  208.25
# IQR =  23.25
# lower limit =  150.125
# upper limit =  243.125
# Outliers =  36     140.0
# 37     140.0
# 38     140.0
# 48     135.0
# 49     135.0
#        ...
# 890    485.0
# 891    590.0
# 892    530.0
# 923    571.0
# 924    571.0
# Name: Mobile Weight(in gram), Length: 125, dtype: float64
# 125

# %% [markdown]
# # Observation:
# # Lower Limit=150
# # Upper Limit=243
# # Total Outliers=125/930 values

# %%
df["RAM(in GB)"].unique()
# Out:
# array([ 6. ,  8. ,  4. ,  3. , 12. ,  2. ,  1.5, 16. , 10. ,  1. ])

# %%
df["RAM(in GB)"].nunique()
# Out:
# 10

# %% [markdown]
# # Observation:- Total 10 different types of RAM inside column "RAM(in GB)"

# %%
df["RAM(in GB)"].value_counts()
# Out:
# RAM(in GB)
# 8.0     308
# 6.0     206
# 12.0    193
# 4.0     146
# 3.0      34
# 16.0     31
# 2.0       6
# 1.5       2
# 10.0      1
# 1.0       1
# Name: count, dtype: int64

# %%
df["RAM(in GB)"].describe()
# Out:
# count    928.000000
# mean       7.784483
# std        3.183086
# min        1.000000
# 25%        6.000000
# 50%        8.000000
# 75%        8.000000
# max       16.000000
# Name: RAM(in GB), dtype: float64

# %% [markdown]
# # Insights & Observations
# # Most Common RAM Size:
# # Since both the median and 75th percentile are 8 GB, it suggests 8 GB RAM is the most common configuration in this dataset.
# # Skewness:
# # The mean (7.78) is slightly less than the median (8), indicating a slight left-skew, though almost symmetrical.
# # There are a few low-end phones (1 GB RAM) and some high-end ones (up to 16 GB), but most cluster around 8 GB.
# # Market Segment Insight:
# # Majority of devices are mid-range (6–8 GB RAM).
# # A minority have very low or very high RAM, suggesting lower sales or availability of those models.
# # Spread:
# # The range is 15 GB (from 1 GB to 16 GB), but most devices fall within a narrower interquartile range (6–8 GB).
# # The standard deviation (3.18) shows moderate variability, with a few extreme values pulling it slightly higher.

# %%
q1=df["RAM(in GB)"].quantile(0.25)
q3=df["RAM(in GB)"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["RAM(in GB)"][(df["RAM(in GB)"]<ll) | (df["RAM(in GB)"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
len(outliers)
# Out:
# Q1 =  6.0
# Q3 =  8.0
# IQR =  2.0
# lower limit =  3.0
# upper limit =  11.0
# Outliers =  97     12.0
# 98     12.0
# 103    12.0
# 104    12.0
# 109    12.0
#        ...
# 888    12.0
# 891    12.0
# 925    12.0
# 926    12.0
# 927    12.0
# Name: RAM(in GB), Length: 233, dtype: float64
# 233

# %% [markdown]
# # Observation:- Total outliers in RAM(in GB)=233

# %%
df["Front Camera"].unique()
# Out:
# array(['12MP', '12MP / 4K', '7MP', '10MP', '32MP', '13MP', '5MP', '16MP',
#        '8MP', '12MP + 12MP', '2MP', '44MP', '24MP', '20MP+8MP', '20MP',
#        '50MP', '25MP', '60MP', '10.7MP', 'Dual 32MP', 'Dual 60MP',
#        '60MP (ultrawide) + 8MP (telephoto)', '60MP + 8MP', '11.1MP',
#        '10.8MP', '10.5MP', '48MP', '42MP', '10MP, 4MP (UDC)'],
#       dtype=object)

# %%
df["Front Camera"].nunique()
# Out:
# 29

# %% [markdown]
# # Observation:- Total 29 types of front camera are present.

# %%
df["Front Camera"].value_counts()
# Out:
# Front Camera
# 16MP                                  211
# 32MP                                  207
# 8MP                                   165
# 12MP                                   81
# 5MP                                    47
# 13MP                                   41
# 12MP / 4K                              36
# 50MP                                   30
# 7MP                                    24
# 10MP                                   22
# 20MP                                   12
# 2MP                                    12
# 10.8MP                                  7
# 60MP                                    5
# 44MP                                    3
# 10.5MP                                  3
# 60MP + 8MP                              3
# 10MP, 4MP (UDC)                         3
# 10.7MP                                  2
# 60MP (ultrawide) + 8MP (telephoto)      2
# 25MP                                    2
# 12MP + 12MP                             2
# ...

# %% [markdown]
# # Observation:- Most cell phone has 16 & 32 MP front camera.

# %%
df["Back Camera"].unique()
# Out:
# array(['48MP', '50MP + 12MP', '48MP + 12MP', '12MP + 12MP', '12MP',
#        '12MP + 12MP + 12MP', '8MP', '12MP + 10MP', '200MP + 12MP',
#        '108MP + 12MP', '48MP + 8MP', '50MP + 5MP', '50MP + 2MP',
#        '108MP + 8MP', '50MP + 8MP', '13MP + 2MP', '12MP + 16MP', '50MP',
#        '16MP', '16MP + 5MP', '13MP', '13MP + 5MP', '16MP + 8MP',
#        '13MP + 8MP', '13MP + 6MP', '5MP', '50MP + 48MP', '108MP',
#        '64MP + 2MP', '48MP + 48MP', '48MP + 50MP', '48MP + 16MP',
#        '48MP + 5MP', '64MP + 8MP', '20MP + 16MP', '16MP + 20MP',
#        '50MP + 16MP', '200MP', '64MP', '13MP+2MP', '48MP + 64MP + 48MP',
#        '50MP + 32MP + 48MP', '50MP + 50MP + 50MP', '50MP + 50MP',
#        '50MP + 8MP + 2MP', '50MP + 50MP + 8MP', '50MP + 32MP + 8MP',
#        '64MP + 8MP + 2MP', '8MP + 2MP', '50MP + 50MP + 64MP',
#        '50MP + 50MP + 13MP', '50MP + 48MP + 32MP', '64MP + 32MP + 8MP',
#        '50MP + 64MP + 8MP', '64MP + 8MP + 2MP + 2MP',
# ...

# %%
df["Back Camera"].nunique()
# Out:
# 90

# %% [markdown]
# # Observation:- Total 90 types of Back Camera are present in phones.

# %%
df["Back Camera"].value_counts()
# Out:
# Back Camera
# 50MP                                                 182
# 13MP                                                  76
# 48MP                                                  60
# 64MP                                                  57
# 50MP + 2MP                                            39
#                                                     ...
# 48MP + 13MP + 8MP + 2MP                                1
# 16MP + 2MP + 2MP                                       1
# 12MP + 8MP + 2MP + 2MP                                 1
# 13MP+2MP                                               1
# 50MP (wide) + 40MP (ultrawide) + 48MP (telephoto)      1
# Name: count, Length: 90, dtype: int64

# %% [markdown]
# # Observation:- 182 phones has 50MP back camera.

# %%
df["Back Camera"].describe()
# Out:
# count      928
# unique      90
# top       50MP
# freq       182
# Name: Back Camera, dtype: object

# %%
df["Processor"].unique().tolist()
# Out:
# ['A17 Bionic',
#  'A17 Pro',
#  'A16 Bionic',
#  'A15 Bionic',
#  'A14 Bionic',
#  'A13 Bionic',
#  'A11 Bionic',
#  'A12 Bionic',
#  'A12Z Bionic',
#  'Exynos 2400',
#  'Snapdragon 8 Gen 2',
#  'Exynos 2200',
#  'Snapdragon 8 Gen 1',
#  'Exynos 1380',
#  'MediaTek Dimensity 1080',
#  'MediaTek Helio G99',
#  'Exynos 850',
#  'Exynos 1280',
#  'MediaTek Helio P35',
#  'Exynos 990',
#  'Exynos 9825',
#  'Snapdragon 450',
#  'Exynos 7870',
#  'Snapdragon 425',
#  'Exynos 7570',
#  'Snapdragon 653',
#  'Snapdragon 625',
#  'Snapdragon 617',
#  'Snapdragon 888',
#  'Snapdragon 695',
#  'Unisoc T618',
#  'MediaTek Helio P22T',
#  'Snapdragon 778G',
#  'Exynos 9810',
#  'Spreadtrum SC8830',
#  'Qualcomm MSM8916',
#  'Snapdragon 8 Gen 3',
#  'MediaTek Dimensity 9000',
#  'Snapdragon 782G',
#  'MediaTek Dimensity 6020',
#  'Snapdragon 8+ Gen 1',
#  'MediaTek Dimensity 1300',
#  'MediaTek Dimensity 1200-AI',
#  'Snapdragon 480',
#  'Qualcomm Snapdragon 460',
#  'Snapdragon 865',
# ...

# %%
df["Processor"].nunique()
# Out:
# 217

# %% [markdown]
# # Observation:- Total 217 different types of processor are present.

# %%
df["Processor"].value_counts()
# Out:
# Processor
# Snapdragon 8 Gen 2         30
# MediaTek Dimensity 810     22
# MediaTek Helio G99         21
# Snapdragon 8 Gen 3         19
# MediaTek Helio G85         19
#                            ..
# Snapdragon 439              1
# Snapdragon 652              1
# MediaTek Helio G35          1
# MediaTek MT6592             1
# MediaTek Dimensity 8400     1
# Name: count, Length: 217, dtype: int64

# %%
df["Processor"].describe()
# Out:
# count                    928
# unique                   217
# top       Snapdragon 8 Gen 2
# freq                      30
# Name: Processor, dtype: object

# %% [markdown]
# # Observation:- Mostly used processor is "Snapdragon 8 Gen 2" which has frequency=30

# %%
df["Battery Capacity(in mAh)"].unique().tolist()
# Out:
# [3600,
#  4200,
#  4400,
#  4500,
#  3200,
#  4300,
#  4325,
#  2438,
#  3240,
#  3095,
#  4352,
#  2227,
#  2815,
#  3687,
#  3110,
#  3046,
#  3969,
#  2716,
#  2658,
#  3174,
#  2942,
#  7608,
#  8612,
#  5124,
#  7812,
#  9720,
#  10307,
#  5000,
#  4800,
#  4000,
#  4700,
#  3900,
#  3800,
#  3700,
#  6000,
#  3500,
#  4050,
#  3000,
#  3300,
#  2600,
#  11200,
#  10090,
#  8400,
#  8000,
#  7040,
#  5100,
#  5050,
#  7600,
#  4510,
#  4115,
#  4085,
#  9510,
#  11000,
#  5700,
#  4100,
#  3315,
#  3260,
#  2300,
#  3055,
#  4030,
#  2000,
#  4450,
#  4600,
#  4830,
#  4870,
#  8040,
#  4805,
#  5800,
#  5600,
#  6400,
#  8360,
#  4520,
#  4350,
#  4025,
#  4040,
#  6500,
#  5500,
#  5200,
#  7100,
#  8340,
#  7200,
#  6100,
#  5400,
#  4610,
#  5110,
#  3350,
#  4310,
#  4020,
#  4360,
#  4460,
#  4815,
#  4750,
#  4900,
#  8200,
#  10100,
#  2800,
#  3140,
#  3885,
#  4080,
#  4680,
#  4614,
#  5003,
#  4410,
#  4355,
#  4385,
#  4575,
#  5250,
#  7500,
#  7000,
#  9000,
# ...

# %%
df["Battery Capacity(in mAh)"].nunique()
# Out:
# 122

# %% [markdown]
# # Observation:- Total 122 unique battery capacity are present .

# %%
df["Battery Capacity(in mAh)"].describe()
# Out:
# count      928.000000
# mean      5026.311422
# std       1356.989874
# min       2000.000000
# 25%       4400.000000
# 50%       5000.000000
# 75%       5073.750000
# max      11200.000000
# Name: Battery Capacity(in mAh), dtype: float64

# %% [markdown]
# # Key Observations
# # Most Common Size:
# # Median = 5000 mAh → Typical for most Android smartphones today.
# # Low-End Devices:
# # Devices with 2000–4000 mAh may be budget phones or older models.
# # High-End / Special Devices:
# # Max = 11200 mAh → These are outliers, possibly:
# # Phones with very large batteries.
# # Tablets or gaming phones.
# # Data entry errors (if suspicious).
# # Spread:
# # Standard deviation of ~1357 mAh is relatively large.
# # Suggests a wide battery size distribution, which might need segmentation.

# %%
q1=df["Battery Capacity(in mAh)"].quantile(0.25)
q3=df["Battery Capacity(in mAh)"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["Battery Capacity(in mAh)"][(df["Battery Capacity(in mAh)"]<ll) | (df["Battery Capacity(in mAh)"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
len(outliers)
# Out:
# Q1 =  4400.0
# Q3 =  5073.75
# IQR =  673.75
# lower limit =  3389.375
# upper limit =  6084.375
# Outliers =  12      3200
# 13      3200
# 14      3200
# 24      3200
# 25      3200
#        ...
# 890     9000
# 891    10500
# 892     8500
# 923    10000
# 924    10000
# Name: Battery Capacity(in mAh), Length: 154, dtype: int64
# 154

# %% [markdown]
# # Observation:- Total outliers are 154.

# %%
df["Screen Size"].unique().tolist()
# Out:
# ['6.1 inches',
#  '6.7 inches',
#  '5.4 inches',
#  '5.8 inches',
#  '6.5 inches',
#  '10.9 inches',
#  '10.2 inches',
#  '7.9 inches',
#  '11 inches',
#  '12.9 inches',
#  '13 inches',
#  '6.8 inches',
#  '6.6 inches',
#  '7.6 inches',
#  '6.4 inches',
#  '6.9 inches',
#  '6.3 inches',
#  '5.3 inches',
#  '6.0 inches',
#  '5.5 inches',
#  '5.7 inches',
#  '5.2 inches',
#  '14.6 inches',
#  '12.4 inches',
#  '8.7 inches',
#  '10.5 inches',
#  '8 inches',
#  '10.1 inches',
#  '6.74 inches',
#  '6.72 inches',
#  '7.8 inches',
#  '6.55 inches',
#  '6.43 inches',
#  '6.49 inches',
#  '6.52 inches',
#  '6.78 inches',
#  '6.59 inches',
#  '6.44 inches',
#  '6.41 inches',
#  '6.01 inches',
#  '6.67 inches',
#  '6.28 inches',
#  '11.61 inches',
#  '6.31 inches',
#  '6.58 inches',
#  '6.38 inches',
#  '6.56 inches',
#  '5.88 inches',
#  '6.22 inches',
#  '5.0 inches',
#  '6.51 inches',
#  '6.35 inches',
#  '6.53 inches',
#  '6.39 inches',
#  '6.47 inches',
#  '10.4 inches',
#  '12.3 inches',
# ...

# %%
df["Launched Price(Pakistan) in PKR"].unique().tolist()
# Out:
# [224999,
#  234999,
#  244999,
#  249999,
#  259999,
#  274999,
#  284999,
#  294999,
#  314999,
#  324999,
#  344999,
#  204999,
#  214999,
#  264999,
#  304999,
#  184999,
#  194999,
#  364999,
#  174999,
#  354999,
#  384999,
#  334999,
#  159999,
#  169999,
#  179999,
#  219999,
#  239999,
#  269999,
#  289999,
#  309999,
#  164999,
#  149999,
#  79999,
#  89999,
#  49999,
#  59999,
#  69999,
#  189999,
#  279999,
#  359999,
#  399999,
#  450000,
#  480000,
#  400000,
#  430000,
#  350000,
#  380000,
#  460000,
#  360000,
#  390000,
#  320000,
#  420000,
#  300000,
#  330000,
#  500000,
#  550000,
#  530000,
#  85000,
#  95000,
#  75000,
#  70000,
#  80000,
#  60000,
#  50000,
#  105000,
#  180000,
#  200000,
#  150000,
#  170000,
#  160000,
#  140000,
#  120000,
#  45000,
#  40000,
#  25000,
#  65000,
#  280000,
#  260000,
#  230000,
#  250000,
#  100000,
#  68000,
#  35000,
#  28000,
#  119999,
#  55000,
#  299999,
#  199999,
#  39999,
#  29999,
#  139999,
#  64999,
#  54999,
# ...

# %%
df["Launched Price(Pakistan) in PKR"].nunique()
# Out:
# 156

# %% [markdown]
# # Observation:-Total 156 unique launched price in Pakistan

# %%
df["Launched Price(Pakistan) in PKR"].describe()
# Out:
# count       928.000000
# mean     125221.017241
# std      101587.167135
# min       15999.000000
# 25%       54999.000000
# 50%       84999.000000
# 75%      179999.000000
# max      604999.000000
# Name: Launched Price(Pakistan) in PKR, dtype: float64

# %% [markdown]
# # Observation:-
# # The mean is much higher than the median, indicating a right-skewed distribution (some very expensive phones are pulling the average up).
# # Standard Deviation: ₹101,587
# # Prices are highly spread out. This is expected in electronics where flagship and budget phones differ drastically.

# %%
q1=df["Launched Price(Pakistan) in PKR"].quantile(0.25)
q3=df["Launched Price(Pakistan) in PKR"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["Launched Price(Pakistan) in PKR"][(df["Launched Price(Pakistan) in PKR"]<ll) | (df["Launched Price(Pakistan) in PKR"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
len(outliers)
# Out:
# Q1 =  54999.0
# Q3 =  179999.0
# IQR =  125000.0
# lower limit =  -132501.0
# upper limit =  367499.0
# Outliers =  47     384999
# 59     384999
# 96     399999
# 97     450000
# 98     480000
# 99     400000
# 100    430000
# 102    380000
# 103    430000
# 104    460000
# 106    390000
# 109    420000
# 110    450000
# 112    380000
# 115    500000
# 116    550000
# 118    380000
# 119    480000
# 120    530000
# 659    389999
# 674    429999
# 677    449999
# 680    469999
# 706    399999
# 717    399999
# 845    369999
# 856    389999
# 867    389999
# 925    604999
# 926    544999
# Name: Launched Price(Pakistan) in PKR, dtype: int64
# 30

# %% [markdown]
# # Observation:-Total 30 outlier in df["Launched Price(Pakistan) in PKR"]

# %%
df["Launched Price(India) in INR"].unique().tolist()
# Out:
# [79999,
#  84999,
#  89999,
#  94999,
#  104999,
#  99999,
#  114999,
#  109999,
#  124999,
#  74999,
#  119999,
#  134999,
#  69999,
#  144999,
#  69900,
#  74900,
#  84900,
#  94900,
#  119900,
#  129900,
#  139900,
#  149900,
#  64900,
#  99900,
#  109900,
#  89900,
#  54900,
#  29900,
#  39900,
#  49900,
#  71900,
#  159900,
#  179900,
#  199900,
#  104900,
#  114900,
#  79900,
#  154900,
#  174900,
#  134900,
#  27999,
#  32999,
#  22999,
#  19999,
#  24999,
#  18499,
#  21999,
#  14999,
#  23999,
#  26999,
#  17999,
#  20999,
#  12999,
#  15999,
#  18999,
#  77999,
#  64999,
#  59999,
#  28999,
#  17499,
#  18990,
#  9990,
#  32990,
#  22990,
#  19990,
#  85999,
#  49999,
#  16999,
#  11999,
#  54999,
#  44999,
#  9999,
#  8499,
#  34999,
#  39999,
#  45999,
#  42999,
#  41999,
#  38999,
#  50999,
#  37999,
#  36999,
#  58999,
#  129999,
#  139999,
#  149999,
#  29999,
#  13999,
#  10999,
#  27990,
#  31990,
#  33990,
#  10990,
#  13990,
#  24990,
#  13490,
#  26990,
#  35990,
# ...

# %%
df["Launched Price(India) in INR"].nunique()
# Out:
# 144

# %% [markdown]
# # Observation:- Total 144 unique values are presemt in column "Launched Price (India)"

# %%
df["Launched Price(India) in INR"].describe()
# Out:
# count       928.000000
# mean      50448.753233
# std       40908.504288
# min        5999.000000
# 25%       19999.000000
# 50%       34999.000000
# 75%       74900.000000
# max      274999.000000
# Name: Launched Price(India) in INR, dtype: float64

# %% [markdown]
# # Observation:-
# # Mean > Median → Right-skewed: A few expensive phones inflate the average
# # Interquartile Range (IQR): ₹54,901 → wide spread among mid-range phones
# # Standard Deviation: ₹40,909 → Prices are highly dispersed, confirming market diversity

# %%
q1=df["Launched Price(India) in INR"].quantile(0.25)
q3=df["Launched Price(India) in INR"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["Launched Price(India) in INR"][(df["Launched Price(India) in INR"]<ll) | (df["Launched Price(India) in INR"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
len(outliers)
# Out:
# Q1 =  19999.0
# Q3 =  74900.0
# IQR =  54901.0
# lower limit =  -62352.5
# upper limit =  157251.5
# Outliers =  94     159900
# 95     179900
# 96     199900
# 116    174900
# 324    159999
# 630    249999
# 634    199999
# 641    249999
# 655    249999
# 658    259999
# 659    274999
# 706    179999
# 717    169999
# 856    159999
# 867    159999
# 925    164999
# 926    176999
# 927    200999
# Name: Launched Price(India) in INR, dtype: int64
# 18

# %% [markdown]
# # Observation:- Total 18 outlier in "Launched Price(India) in INR"

# %%
df["Launched Price(China) in CNY"].unique().tolist()
# Out:
# [5799,
#  6099,
#  6499,
#  6199,
#  6999,
#  7099,
#  7499,
#  7799,
#  8199,
#  5299,
#  5599,
#  5999,
#  5699,
#  6799,
#  7299,
#  7999,
#  8699,
#  5199,
#  5499,
#  5899,
#  6299,
#  7199,
#  8099,
#  8499,
#  8999,
#  7699,
#  8299,
#  8799,
#  9199,
#  8399,
#  7399,
#  8388,
#  8788,
#  9188,
#  9788,
#  10388,
#  10088,
#  10688,
#  11288,
#  3299,
#  3699,
#  2299,
#  2699,
#  3499,
#  3799,
#  6399,
#  9799,
#  10399,
#  11199,
#  6599,
#  11999,
#  12999,
#  10999,
#  2199,
#  2499,
#  1799,
#  1999,
#  1599,
#  1499,
#  1699,
#  1199,
#  1399,
#  2099,
#  1099,
#  1299,
#  2399,
#  999,
#  3099,
#  1899,
#  9999,
#  9499,
#  4299,
#  2999,
#  899,
#  799,
#  4999,
#  2799,
#  4699,
#  4199,
#  3199,
#  3899,
#  3999,
#  4499,
#  4599,
#  3599,
#  3399,
#  3400,
#  3600,
#  2800,
#  2900,
#  3000,
#  2700,
#  2600,
#  2400,
#  2500,
#  2000,
#  2100,
#  1800,
#  1900,
#  1500,
#  1600,
#  2200,
#  1400,
#  1700,
#  1200,
#  1100,
#  900,
#  1300,
#  1050,
#  3200,
# ...

# %%
df["Launched Price(China) in CNY"].nunique()
# Out:
# 135

# %% [markdown]
# # Observation:- Total 135 unique values are presemt in column "Launched Price (China)"

# %%
df["Launched Price(China) in CNY"].describe()
# Out:
# count      928.000000
# mean      3811.372845
# std       2760.446211
# min        499.000000
# 25%       1699.000000
# 50%       2800.000000
# 75%       5499.000000
# max      17999.000000
# Name: Launched Price(China) in CNY, dtype: float64

# %% [markdown]
# # Observation:-
# # Mean > Median :Right-skewed distribution, pulled up by high-end phones
# # Interquartile Range (IQR): 800 indicates significant spread among typical devices
# # Standard Deviation: 760 Moderate to high variation in prices

# %%
q1=df["Launched Price(China) in CNY"].quantile(0.25)
q3=df["Launched Price(China) in CNY"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["Launched Price(China) in CNY"][(df["Launched Price(China) in CNY"]<ll) | (df["Launched Price(China) in CNY"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
len(outliers)
# Out:
# Q1 =  1699.0
# Q3 =  5499.0
# IQR =  3800.0
# lower limit =  -4001.0
# upper limit =  11199.0
# Outliers =  76     11288
# 115    11999
# 116    12999
# 120    11999
# 630    17999
# 634    14999
# 641    13999
# 655    12999
# 658    13499
# 659    14499
# 706    13999
# 717    12999
# 925    13999
# 926    15999
# 927    17999
# Name: Launched Price(China) in CNY, dtype: int64
# 15

# %% [markdown]
# # Observation:- Total 15 outlier in "Launched Price(China) in CNY"

# %%
df["Launched Price(USA) in USD"].unique().tolist()
# Out:
# [799.0,
#  849.0,
#  899.0,
#  949.0,
#  999.0,
#  1049.0,
#  1099.0,
#  1199.0,
#  1299.0,
#  1399.0,
#  699.0,
#  1249.0,
#  749.0,
#  599.0,
#  329.0,
#  429.0,
#  399.0,
#  499.0,
#  1599.0,
#  1799.0,
#  1899.0,
#  449.0,
#  349.0,
#  299.0,
#  249.0,
#  199.0,
#  179.0,
#  169.0,
#  129.0,
#  1499.0,
#  549.0,
#  229.0,
#  149.0,
#  649.0,
#  99.0,
#  219.0,
#  139.0,
#  159.0,
#  269.0,
#  319.0,
#  239.0,
#  279.0,
#  189.0,
#  259.0,
#  470.0,
#  500.0,
#  380.0,
#  400.0,
#  420.0,
#  360.0,
#  340.0,
#  320.0,
#  270.0,
#  290.0,
#  250.0,
#  220.0,
#  240.0,
#  300.0,
#  200.0,
#  260.0,
#  180.0,
#  160.0,
#  210.0,
#  230.0,
#  130.0,
#  170.0,
#  190.0,
#  150.0,
#  440.0,
#  330.0,
#  350.0,
#  280.0,
#  310.0,
#  634.99,
#  790.77,
#  374.9,
#  379.0,
#  309.0,
#  479.0,
#  370.0,
#  450.0,
#  2699.0,
#  2499.0,
#  2599.0,
#  2799.0,
#  529.0,
#  729.0,
#  119.0,
#  1699.0,
#  39622.0,
#  877.0,
#  89.0,
#  289.0,
#  109.0,
#  79.0,
#  1719.0,
#  2259.0]

# %%
df["Launched Price(USA) in USD"].nunique()
# Out:
# 97

# %% [markdown]
# # Observation:- Total 97 unique values are presemt in column "Launched Price (USA)"

# %%
df["Launched Price(USA) in USD"].describe()
# Out:
# count      928.000000
# mean       624.279806
# std       1348.742522
# min         79.000000
# 25%        250.000000
# 50%        449.000000
# 75%        849.000000
# max      39622.000000
# Name: Launched Price(USA) in USD, dtype: float64

# %% [markdown]
# # Observation:-
# # Mean > Median → Strong right-skew, with a few high prices pulling up the average
# # Interquartile Range (IQR): 599
# # Suggests most phones are between 250–849 (budget to upper mid-range)
# # Standard Deviation: 1,348.74
# # Very high variation in prices, likely due to outliers

# %%
q1=df["Launched Price(USA) in USD"].quantile(0.25)
q3=df["Launched Price(USA) in USD"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["Launched Price(USA) in USD"][(df["Launched Price(USA) in USD"]<ll) | (df["Launched Price(USA) in USD"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
len(outliers)
# Out:
# Q1 =  250.0
# Q3 =  849.0
# IQR =  599.0
# lower limit =  -648.5
# upper limit =  1747.5
# Outliers =  96      1799.0
# 115     1799.0
# 116     1899.0
# 119     1799.0
# 120     1899.0
# 630     2699.0
# 634     2499.0
# 641     2499.0
# 655     2499.0
# 658     2599.0
# 659     2799.0
# 680     1799.0
# 683    39622.0
# 706     1799.0
# 717     1799.0
# 834     1799.0
# 856     1899.0
# 867     1899.0
# 925     1899.0
# 927     2259.0
# Name: Launched Price(USA) in USD, dtype: float64
# 20

# %% [markdown]
# # Observation:- Total 20 outlier in "Launched Price(USA) in USD"

# %%
df["Launched Price(Dubai) in AED"].unique().tolist()
# Out:
# [2799,
#  2999,
#  3199,
#  3399,
#  3599,
#  3499,
#  3699,
#  3899,
#  3799,
#  3999,
#  4199,
#  2699,
#  4399,
#  4499,
#  2599,
#  3299,
#  4599,
#  2499,
#  4999,
#  4299,
#  4799,
#  5099,
#  3099,
#  2099,
#  1199,
#  1499,
#  1799,
#  5299,
#  5799,
#  6099,
#  4899,
#  6999,
#  7499,
#  4099,
#  6499,
#  7099,
#  1399,
#  1299,
#  1099,
#  899,
#  999,
#  1699,
#  799,
#  699,
#  499,
#  5499,
#  1999,
#  599,
#  2199,
#  1899,
#  399,
#  2899,
#  2299,
#  2399,
#  4699,
#  1649,
#  549,
#  649,
#  1599,
#  749,
#  5199,
#  1000,
#  1200,
#  1300,
#  1100,
#  950,
#  900,
#  850,
#  800,
#  750,
#  700,
#  1500,
#  1700,
#  1400,
#  1725,
#  1840,
#  1460,
#  1520,
#  1330,
#  1250,
#  1320,
#  1150,
#  1210,
#  970,
#  1030,
#  860,
#  1070,
#  1140,
#  1390,
#  960,
#  1280,
#  720,
#  780,
#  1020,
#  920,
#  660,
#  600,
#  830,
#  500,
#  620,
#  680,
#  580,
#  820,
#  880,
#  1620,
#  1800,
#  740,
#  1050,
#  770,
#  730,
#  849,
#  949,
#  1049,
#  1175,
#  1350,
# ...

# %%
df["Launched Price(Dubai) in AED"].nunique()
# Out:
# 141

# %% [markdown]
# # Observation:- Total 141 unique values are presemt in column "Launched Price (Dubai)"

# %%
df["Launched Price(Dubai) in AED"].describe()
# Out:
# count      928.000000
# mean      2178.943966
# std       1563.556403
# min        299.000000
# 25%       1000.000000
# 50%       1675.000000
# 75%       3199.000000
# max      11099.000000
# Name: Launched Price(Dubai) in AED, dtype: float64

# %% [markdown]
# # Observation:-
# # Since mean > median, the data is right-skewed (influenced by higher-priced models)
# # Interquartile Range (IQR): AED 2,199, indicating wide price variation in mainstream devices
# # Standard Deviation: AED 1,563.56
# # Moderate to high variation, supporting the presence of diverse pricing tiers

# %%
q1=df["Launched Price(Dubai) in AED"].quantile(0.25)
q3=df["Launched Price(Dubai) in AED"].quantile(0.75)
IQR=q3-q1
ll=q1-1.5*IQR
ul=q3+1.5*IQR
outliers=df["Launched Price(Dubai) in AED"][(df["Launched Price(Dubai) in AED"]<ll) | (df["Launched Price(Dubai) in AED"]>ul)]
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",IQR)
print("lower limit = ",ll)
print("upper limit = ",ul)
print("Outliers = ",outliers)
len(outliers)
# Out:
# Q1 =  1000.0
# Q3 =  3199.0
# IQR =  2199.0
# lower limit =  -2298.5
# upper limit =  6497.5
# Outliers =  115     6999
# 116     7499
# 119     6499
# 120     7099
# 630     9999
# 634     8999
# 641     9999
# 655     9999
# 658    10499
# 659    11099
# 706     6999
# 717     6999
# 834     6599
# 856     6999
# 867     6999
# 925     7199
# 926     7699
# 927     8699
# Name: Launched Price(Dubai) in AED, dtype: int64
# 18

# %% [markdown]
# # Observation:- Total 18 outlier in "Launched Price(USA) in USD"

# %%
df["Launched Year"].unique().tolist()
# Out:
# [Timestamp('2024-01-01 00:00:00'),
#  Timestamp('2023-01-01 00:00:00'),
#  Timestamp('2022-01-01 00:00:00'),
#  Timestamp('2021-01-01 00:00:00'),
#  Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2019-01-01 00:00:00'),
#  Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2016-01-01 00:00:00'),
#  Timestamp('2014-01-01 00:00:00'),
#  Timestamp('2025-01-01 00:00:00')]

# %%
df["Launched Year"].nunique()
# Out:
# 11

# %% [markdown]
# # Observation:- Total 11 unique year in "Launched Year" column.

# %%
df["Launched Year"].mode()
# Out:
# 0   2024-01-01
# Name: Launched Year, dtype: datetime64[ns]

# %% [markdown]
# # Observation:- Mostly cell phone are launched in 2024 year

# %%
df["Launched Year"].value_counts()
# Out:
# Launched Year
# 2024-01-01    292
# 2023-01-01    182
# 2022-01-01    149
# 2021-01-01    109
# 2020-01-01    101
# 2019-01-01     46
# 2018-01-01     21
# 2025-01-01     12
# 2017-01-01      9
# 2016-01-01      5
# 2014-01-01      2
# Name: count, dtype: int64

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
df["Mobile Weight(in gram)"].cov(df["RAM(in GB)"])
# Out:
# -2.4835918610274077

# %% [markdown]
# # Observation:- As RAM increases, mobile weight tends to slightly decrease (but this is very weak).

# %%
df["Mobile Weight(in gram)"].corr(df["RAM(in GB)"])
# Out:
# -0.007392931179352863

# %% [markdown]
# # Observation:-Your correlation is very close to 0:
# # r = -0.0074 means virtually no linear relationship between mobile weight and RAM.

# %%
df["Mobile Weight(in gram)"].cov(df["Battery Capacity(in mAh)"])
# Out:
# 121413.42898765007

# %% [markdown]
# # Observation:-Covariance is positive and large, indicating that as battery capacity increases, mobile weight also tends to increase.

# %%
df["Mobile Weight(in gram)"].corr(df["Battery Capacity(in mAh)"])
# Out:
# 0.8477638554678385

# %% [markdown]
# # Observation:-There is a strong, positive linear relationship between battery capacity and mobile weight. Heavier phones tend to have larger batteries.

# %%
df["Mobile Weight(in gram)"].cov(df["Launched Price(Pakistan) in PKR"])
# Out:
# 1093276.8425622138

# %% [markdown]
# # Observation:-The covariance is positive, so as mobile weight increases, the launch price also tends to increase — but this only tells the direction.

# %%
df["Mobile Weight(in gram)"].corr(df["Launched Price(Pakistan) in PKR"])
# Out:
# 0.10197085903351634

# %% [markdown]
# # This is a very weak positive correlation.
# # Interpretation:
# # Heavier phones tend to be slightly more expensive, but the relationship is very weak.

# %%
df["Mobile Weight(in gram)"].cov(df["Launched Price(India) in INR"])
# Out:
# 617298.5637921734

# %% [markdown]
# # Observation:-Covariance is positive, indicating that as weight increases, price in INR tends to increase, similar to the Pakistan price relationship.

# %%
df["Mobile Weight(in gram)"].corr(df["Launched Price(India) in INR"])
# Out:
# 0.14297708686890567

# %% [markdown]
# # Observation:-This is a weak positive correlation.

# %%
df["Mobile Weight(in gram)"].cov(df["Launched Price(China) in CNY"])
# Out:
# 40446.788072387746

# %% [markdown]
# # Observation:-This positive covariance suggests a positive direction:

# %%
df["Mobile Weight(in gram)"].corr(df["Launched Price(China) in CNY"])
# Out:
# 0.13883198366654537

# %% [markdown]
# # Observation:-There is a weak positive linear relationship between mobile weight and launched price in China

# %%
df["Mobile Weight(in gram)"].cov(df["Launched Price(USA) in USD"])
# Out:
# 14969.325745285125

# %% [markdown]
# # Observation:-Covariance is positive, indicating that as phone weight increases, the launch price in USD tends to increase.

# %%
df["Mobile Weight(in gram)"].corr(df["Launched Price(USA) in USD"])
# Out:
# 0.10516178953757893

# %% [markdown]
# # Observation:-This is a very weak positive correlation.

# %%
df["Mobile Weight(in gram)"].cov(df["Launched Price(Dubai) in AED"])
# Out:
# 16640.891392329715

# %% [markdown]
# # Observation:-This positive covariance again indicates that as phone weight increases, the price in AED tends to increase.

# %%
df["Mobile Weight(in gram)"].corr(df["Launched Price(Dubai) in AED"])
# Out:
# 0.10084347723499908

# %% [markdown]
# # Observation:-This positive covariance again indicates that as phone weight increases, the price in AED tends to increase.

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
df["RAM(in GB)"].cov(df["Battery Capacity(in mAh)"])
# Out:
# 601.3616876836671

# %% [markdown]
# # Observation:-This positive value indicates that as RAM increases, battery capacity also tends to increase

# %%
df["RAM(in GB)"].corr(df["Battery Capacity(in mAh)"])
# Out:
# 0.1392229417408612

# %% [markdown]
# # Conclusion
# # There's a weak positive linear relationship between RAM and battery capacity

# %%
df["RAM(in GB)"].cov(df["Launched Price(Pakistan) in PKR"])
# Out:
# 133359.06412974742

# %% [markdown]
# # Observation:-This positive covariance shows that as RAM increases, the launch price in PKR tends to increase.

# %%
df["RAM(in GB)"].corr(df["Launched Price(Pakistan) in PKR"])
# Out:
# 0.4124158485240667

# %% [markdown]
# # Conclusion
# # There is a moderate, meaningful positive relationship between RAM and launch price. Unlike weight or battery, RAM has a stronger impact on pricing, likely because it's a key performance spec consumers care about.

# %%
df["RAM(in GB)"].cov(df["Launched Price(India) in INR"])
# Out:
# 55070.99422497491

# %% [markdown]
# # Observation:-A positive value, so as RAM increases, price in INR increases.

# %%
df["RAM(in GB)"].corr(df["Launched Price(India) in INR"])
# Out:
# 0.42292267746581097

# %% [markdown]
# # Conclusion
# # There's a moderate, consistent positive relationship between RAM and phone price in India. RAM is a better predictor of price than weight or battery capacity.

# %%
df["RAM(in GB)"].cov(df["Launched Price(China) in CNY"])
# Out:
# 3768.4849719153367

# %% [markdown]
# # Observation:-Positive value → as RAM increases, price in CNY increases.

# %%
df["RAM(in GB)"].corr(df["Launched Price(China) in CNY"])
# Out:
# 0.42888331943929975

# %% [markdown]
# # Conclusion
# # There is a moderate, positive linear relationship between RAM and phone price in China. RAM continues to be one of the most price-influencing features.

# %%
df["RAM(in GB)"].cov(df["Launched Price(USA) in USD"])
# Out:
# 465.83495275824845

# %% [markdown]
# # Observation:-This positive value again shows a positive directional relationship — more RAM tends to be associated with higher prices in the U.S.

# %%
df["RAM(in GB)"].corr(df["Launched Price(USA) in USD"])
# Out:
# 0.10850623107756366

# %% [markdown]
# # Observation:-
# # There's a very weak linear relationship between RAM and launch price in USD. Unlike Asian markets, RAM may not strongly influence pricing in the U.S.

# %%
df["RAM(in GB)"].cov(df["Launched Price(Dubai) in AED"])
# Out:
# 2383.589852323029

# %% [markdown]
# # Covariance: 2,383.59
# # A positive value, again showing that phones with more RAM tend to cost more in Dubai.

# %%
df["RAM(in GB)"].corr(df["Launched Price(Dubai) in AED"])
# Out:
# 0.47892734276981697

# %% [markdown]
# # This is the highest correlation you've seen so far in your RAM vs Price analysis across all countries.

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
df["Battery Capacity(in mAh)"].cov(df["Launched Price(Pakistan) in PKR"])
# Out:
# -5602950.684986787

# %% [markdown]
# # Obsevation:-This large negative value (due to the scale of mAh and PKR) indicates that as battery capacity increases, price tends to decrease

# %%
df["Battery Capacity(in mAh)"].corr(df["Launched Price(Pakistan) in PKR"])
# Out:
# -0.040644458639213364

# %% [markdown]
# # Conclusion:
# # There is no meaningful relationship between battery size and phone price in the Pakistani market.

# %%
df["Battery Capacity(in mAh)"].cov(df["Launched Price(India) in INR"])
# Out:
# -429859.46028507757

# %% [markdown]
# # Covariance: -429,859.46
# # A negative value, but it doesn’t mean much on its own due to different unit scales.

# %%
df["Battery Capacity(in mAh)"].corr(df["Launched Price(India) in INR"])
# Out:
# -0.007743481787495949

# %% [markdown]
# # Conclusion:
# # Just like in Pakistan, battery size does not influence price in India.

# %%
df["Battery Capacity(in mAh)"].cov(df["Launched Price(China) in CNY"])
# Out:
# -88092.22303360859

# %%
df["Battery Capacity(in mAh)"].corr(df["Launched Price(China) in CNY"])
# Out:
# -0.02351698671161485

# %% [markdown]
# # Observation:-In China, as battery capacity increases, price very slightly decreases, but this is not meaningful.
# # Just like India and Pakistan, battery capacity doesn’t impact price in a significant way.

# %%
df["Battery Capacity(in mAh)"].cov(df["Launched Price(USA) in USD"])
# Out:
# 117084.50051354484

# %%
df["Battery Capacity(in mAh)"].corr(df["Launched Price(USA) in USD"])
# Out:
# 0.06397256303440156

# %% [markdown]
# # A very weak positive correlation between battery capacity and price.

# %%
df["Battery Capacity(in mAh)"].cov(df["Launched Price(Dubai) in AED"])
# Out:
# -80470.01812948717

# %% [markdown]
# # Observation:-Positive, but the absolute value is modest.

# %%
df["Battery Capacity(in mAh)"].corr(df["Launched Price(Dubai) in AED"])
# Out:
# -0.03792660250069456

# %% [markdown]
# # Correlation: +0.0640
# # A very weak positive correlation between battery capacity and price

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
df["Launched Price(Pakistan) in PKR"].cov(df["Launched Price(India) in INR"])
# Out:
# 3724033997.190882

# %% [markdown]
# # Covariance:
# # The large positive covariance suggests that as prices increase in Pakistan, they also increase in India.

# %%
df["Launched Price(Pakistan) in PKR"].corr(df["Launched Price(India) in INR"])
# Out:
# 0.8961097164485887

# %% [markdown]
# # Correlation r = 0.896:
# # This is a very strong positive correlation (close to +1).
# # Meaning:
# # When a phone is expensive in Pakistan, it is very likely also expensive in India — and vice versa.

# %%
df["Launched Price(Pakistan) in PKR"].cov(df["Launched Price(China) in CNY"])
# Out:
# 249104907.7120112

# %% [markdown]
# # Covariance:
# # High and positive, but again, not directly comparable due to different units (PKR·CNY)

# %%
df["Launched Price(Pakistan) in PKR"].corr(df["Launched Price(China) in CNY"])
# Out:
# 0.8883091694149211

# %% [markdown]
# # Correlation: 0.8883
# # Very strong positive linear correlation
# # Meaning:
# # As the price of phones increases in Pakistan, it strongly increases in China as well.

# %%
df["Launched Price(Pakistan) in PKR"].cov(df["Launched Price(USA) in USD"])
# Out:
# 34831572.05394077

# %% [markdown]
# # Covariance:
# # Positive, but relatively lower than previous country pairs.

# %%
df["Launched Price(Pakistan) in PKR"].corr(df["Launched Price(USA) in USD"])
# Out:
# 0.25421734364228094

# %% [markdown]
# # Correlation (r = 0.25):
# # Weak to moderate positive correlation
# # Meaning:
# # As prices increase in Pakistan, there’s a slight tendency for prices to also increase in the USA, but not strongly

# %%
df["Launched Price(Pakistan) in PKR"].cov(df["Launched Price(Dubai) in AED"])
# Out:
# 141103739.89848608

# %% [markdown]
# # Covariance:
# # High and positive — indicates that as prices rise in Pakistan, they also tend to rise in Dubai.

# %%
df["Launched Price(Pakistan) in PKR"].corr(df["Launched Price(Dubai) in AED"])
# Out:
# 0.8883541236508287

# %% [markdown]
# # Correlation (r = 0.8884):
# # Very strong positive correlation
# #  Meaning:
# # Mobile phone launch prices in Pakistan and Dubai are strongly aligned — a price increase in one country generally reflects a similar increase in the other.

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
df["Launched Price(India) in INR"].cov(df["Launched Price(China) in CNY"])
# Out:
# 109134785.6541332

# %% [markdown]
# # Covariance:
# # Very large and positive

# %%
df["Launched Price(India) in INR"].corr(df["Launched Price(China) in CNY"])
# Out:
# 0.9664297929045976

# %% [markdown]
# # Extremely strong positive correlation
# # This indicates that mobile phone launch prices in India and China are almost perfectly aligned.

# %%
df["Launched Price(India) in INR"].cov(df["Launched Price(USA) in USD"])
# Out:
# 15300540.2233825

# %% [markdown]
# # Covariance:
# # Positive: When the Launched Price in India increases, the Launched Price in the USA tends to increase too.

# %%
df["Launched Price(India) in INR"].corr(df["Launched Price(USA) in USD"])
# Out:
# 0.2773090954295506

# %% [markdown]
# # Correlation (r = 0.2773):
# # This is a weak to moderate positive correlation.
# # It means: Prices in India and the USA are somewhat aligned, but not tightly.

# %%
df["Launched Price(India) in INR"].cov(df["Launched Price(Dubai) in AED"])
# Out:
# 62000064.71754917

# %% [markdown]
# # Covariance:
# # Positive and large — prices in India and Dubai tend to increase or decrease together.

# %%
df["Launched Price(India) in INR"].corr(df["Launched Price(Dubai) in AED"])
# Out:
# 0.9693151252338233

# %% [markdown]
# # Correlation (r = 0.9693):
# # This is a very strong positive correlation.
# # Indicates that Launched Price in India and Dubai move almost in sync.

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
df["Launched Price(China) in CNY"].cov(df["Launched Price(USA) in USD"])
# Out:
# 1014636.464150067

# %% [markdown]
# # Covariance:
# # Positive — this means that as price in China (CNY) increases, price in USA (USD) also tends to increase.

# %%
df["Launched Price(China) in CNY"].corr(df["Launched Price(USA) in USD"])
# Out:
# 0.272522351200403

# %% [markdown]
# # Correlation (r = 0.2725):
# # This is a weak to moderate positive correlation.
# # Suggests there is some positive relationship, but not very strong.
# # In other words: Phones priced higher in China are somewhat more likely to be priced higher in the USA, but not always.

# %%
df["Launched Price(China) in CNY"].cov(df["Launched Price(Dubai) in AED"])
# Out:
# 4182843.9033311005

# %% [markdown]
# #  Covariance:
# # The positive value shows that prices in China and Dubai tend to increase together.

# %%
df["Launched Price(China) in CNY"].corr(df["Launched Price(Dubai) in AED"])
# Out:
# 0.9691228118091056

# %% [markdown]
# # Correlation (r ≈ 0.97):
# # This is a very strong positive linear correlation.
# # It suggests that mobile phone prices in China and Dubai move almost in lockstep.
# # A high price in China is highly likely to correspond to a high price in Dubai, and vice versa.

# %%
df["Launched Price(USA) in USD"].cov(df["Launched Price(Dubai) in AED"])
# Out:
# 595688.0418014168

# %%
df["Launched Price(USA) in USD"].corr(df["Launched Price(Dubai) in AED"])
# Out:
# 0.2824725690278204

# %% [markdown]
# # Meaning
# # Covariance → Positive, so prices in the USA and Dubai tend to move in the same direction (if one goes up, the other often does too).
# # Correlation (~0.28) → Weak positive linear relationship.
# # This means there’s some alignment in pricing, but it’s not strong.
# # Price changes in the USA don’t strongly predict price changes in Dubai.

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %% [markdown]
# # Product Performance & Pricing
# # Q.1 Which company offers the highest average RAM across all models? (Bar chart)

# %%
avg_ram_per_company =df.groupby("Company Name")["RAM(in GB)"].mean().sort_values(ascending=False)

# %%
avg_ram_per_company
# Out:
# Company Name
# Xiaomi      10.518519
# Huawei       9.800000
# OnePlus      9.433962
# Oppo         9.255814
# Sony         8.666667
# Google       8.571429
# Realme       8.130435
# Honor        8.010989
# Motorola     7.548387
# Samsung      7.511364
# Vivo         7.500000
# iQOO         7.333333
# Tecno        7.205128
# Infinix      6.839286
# Lenovo       6.333333
# POCO         5.937500
# Apple        5.329897
# Nokia        4.000000
# Name: RAM(in GB), dtype: float64

# %%
# Count plot for internal storage
plt.figure(figsize=(10,6))
sns.countplot(
    data=df,
    x='RAM(in GB)',
    order=df['RAM(in GB)'].value_counts().index
)

plt.title("Distribution of Internal Storage Capacities", fontsize=14)
plt.xlabel("RAM(in GB)")
plt.ylabel("Number of Smartphones")
plt.tight_layout()
plt.show()

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
plt.figure(figsize=(10,6))
plt.pie(x=df["Company Name"].value_counts().values,labels=df["Company Name"].value_counts().index,autopct="%0.1f%%",labeldistance=1.2,pctdistance=0.7)
plt.title("Distribution of Mobile Phones(%wise) As Per Company")
plt.show()

# %% [markdown]
# # Observation:- No.of company who has more number of mobile phones:-
# # 1.Oppo
# # 2.Apple
# # 3.Honor
# # 4.Samsung
# # 5.Vivo
# # 6.Realme
# # 7.Motorola
# # 8.Infinix
# # 9.OnePlus

# %%
plt.figure(figsize=(10,6))
ax=sns.countplot(x="Company Name",data=df)
ax.bar_label(ax.containers[0])
plt.xticks(rotation=45,ha="right")
plt.title("Distribution of Mobile Phones As Per Company")
plt.show()

# %% [markdown]
# # Observation:- No.of company who has more number of mobile phones:-
# # 1.Oppo=129
# # 2.Apple=97
# # 3.Honor=91
# # 4.Samsung=88
# # 5.Vivo=86
# # 6.Realme=69
# # 7.Motorola=62
# # 8.Infinix=56
# # 9.OnePlus=53
# # but some other companies also which has less number of phone as compared to above.

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(x="Company Name",y="RAM(in GB)",data=df)
ax.bar_label(ax.containers[0],color="green",padding=30,fmt="%.1f")
plt.xticks(rotation=45,ha="right")
plt.title("Company name v/s Average RAM(in GB)")
plt.show()

# %% [markdown]
# # Observation:- Each company and their average GB
# # 1.Oppo=129   -->(9.3GB)
# # 2.Apple=97   -->(5.3GB)
# # 3.Honor=91   -->(8.0GB)
# # 4.Samsung=88 -->(7.5GB)                           xiaomi=27-->(10.5GB)
# # 5.Vivo=86    -->(7.5GB)
# # 6.Realme=69  -->(8.1GB)
# # 7.Motorola=62-->(7.5GB)
# # 8.Infinix=56 -->(6.8GB)
# # 9.OnePlus=53 -->(9.4GB)

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(x="Company Name",y="Mobile Weight(in gram)",data=df)
ax.bar_label(ax.containers[0],color="Red",padding=15,fmt="%.1f")
plt.xticks(rotation=45,ha="right")
plt.title("Mobile Weight(in gram) of each Company")
plt.show()

# %% [markdown]
# # Observation:-
# # 1.Oppo    =129-->(205.4 mAh)
# # 2.Apple   =97 -->(258.1 mAh)
# # 3.Honor   =91 -->(284.8 mAh)
# # 4.Samsung =88 -->(256.7 mAh)
# # 5.Vivo    =86 -->(208.5 mAh)
# # 6.Realme  =69 -->(245.2 mAh)
# # 7.Motorola=62 -->(182.4 mAh)
# # 8.Infinix =56 -->(216.3 mAh)
# # 9.xiaomi  =27 -->(197.1 mAh)
# # 10.iQOO  =3 -->(538.3 mAh)

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
sns.scatterplot(x="Mobile Weight(in gram)",y="Battery Capacity(in mAh)",data=df)
plt.title("Relationship b/w Mobile Weight(in gram) & Battery Capacity(in mAh)")
# Out:
# Text(0.5, 1.0, 'Relationship b/w Mobile Weight(in gram) & Battery Capacity(in mAh)')

# %% [markdown]
# # Observation:- Linear relationship as mobile weight increases battery capacity also increases

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(x="Company Name",y="Launched Price(Pakistan) in PKR",data=df)
ax.bar_label(ax.containers[0],color="green",padding=30,fmt="%.1f")
plt.xticks(rotation=45,ha="right")
plt.title("Company name v/s Average Launched Price(Pakistan) in PKR")
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(x="Company Name",y="Launched Price(India) in INR",data=df)
ax.bar_label(ax.containers[0],color="green",padding=30,fmt="%.1f")
plt.xticks(rotation=45,ha="right")
plt.title("Company name v/s Average Launched Price(India) in INR")
plt.show()

# %%
sns.scatterplot(x="Launched Price(Pakistan) in PKR",y="Launched Price(India) in INR",data=df)
plt.title("Launched Price(Pakistan) in PKR & Launched Price(India) in INR")
# Out:
# Text(0.5, 1.0, 'Launched Price(Pakistan) in PKR & Launched Price(India) in INR')

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(x="Company Name",y="Launched Price(China) in CNY",data=df)
ax.bar_label(ax.containers[0],color="green",padding=30,fmt="%.1f")
plt.xticks(rotation=45,ha="right")
plt.title("Company name v/s Average Launched Price(China) in CNY")
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.pairplot(df[["Launched Price(Pakistan) in PKR","Launched Price(India) in INR","Launched Price(China) in CNY"]])
height=3
plt.yticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(x="Company Name",y="Launched Price(Dubai) in AED",data=df)
ax.bar_label(ax.containers[0],color="green",padding=30,fmt="%.1f")
plt.xticks(rotation=45,ha="right")
plt.title("Company name v/s Average Launched Price(Dubai) in AED")
plt.show()

# %%
df.head(1)
# Out:
#   Company Name       Model Name  Mobile Weight(in gram)  RAM(in GB)  \
# 0        Apple  iPhone 16 128GB                   174.0         6.0
#
#   Front Camera Back Camera   Processor  Battery Capacity(in mAh) Screen Size  \
# 0         12MP        48MP  A17 Bionic                      3600  6.1 inches
#
#    Launched Price(Pakistan) in PKR  Launched Price(India) in INR  \
# 0                           224999                         79999
#
#    Launched Price(China) in CNY  Launched Price(USA) in USD  \
# 0                          5799                       799.0
#
#    Launched Price(Dubai) in AED Launched Year
# 0                          2799    2024-01-01

# %%
sns.heatmap(df[["Launched Price(Pakistan) in PKR",
    "Launched Price(India) in INR",
    "Launched Price(China) in CNY",
    "Launched Price(USA) in USD",
    "Launched Price(Dubai) in AED"]].corr(),annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Price Correlation Heatmap")
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(India) in INR", label="India")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(Pakistan) in PKR", label="Pakistan")

plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(China) in CNY", label="China")


plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(India) in INR", label="India")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(Pakistan) in PKR", label="Pakistan")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(China) in CNY", label="China")


plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(USA) in USD", label="USA")


plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(China) in CNY", label="China")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(USA) in USD", label="USA")


plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(India) in INR", label="India")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(Pakistan) in PKR", label="Pakistan")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(China) in CNY", label="China")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(USA) in USD", label="USA")


plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(Dubai) in AED", label="Dubai")


plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()

# %%
# Example: comparing two countries' prices over index
sns.lineplot(data=df, x="Launched Year", y="Launched Price(India) in INR", label="India")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(Pakistan) in PKR", label="Pakistan")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(China) in CNY", label="China")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(USA) in USD", label="USA")
sns.lineplot(data=df, x="Launched Year", y="Launched Price(Dubai) in AED", label="Dubai")

plt.xlabel("Launched Year")
plt.ylabel("Price")
plt.title("Price Comparison Over Years")
plt.legend()
plt.show()
